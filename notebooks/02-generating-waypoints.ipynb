# %% [markdown]
# # Class 02: Understanding the Waypoints
#
# ## Where to found track info?
#
# [deepracer-race-data: Tracks drawings link github repo](https://github.com/aws-deepracer-community/deepracer-race-data/tree/main/raw_data/tracks)

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np

from deepracer.tracks import TrackIO, Track
from deepracer.tracks.track_utils import track_breakdown, track_meta
from deepracer.logs import SimulationLogsIO as slio, \
    NewRewardUtils as nr, \
    AnalysisUtils as au, \
    PlottingUtils as pu, \
    ActionBreakdownUtils as abu, \
    DeepRacerLog

# %% [markdown]
# ### 2. Tracks

# %% [markdown]
# #### A to Z - wide

# %%
waypoints = np.load("../data/reInvent2019_wide.npy")
track = Track("A to Z - Wide", waypoints)
pu.plot_trackpoints(track);
plt.savefig("../assets/aToZ-wide.png");

# %% [markdown]
# #### A to Z - Counter Clock Wise

# %%
waypoints = np.load("../data/reInvent2019_wide_ccw.npy")
track = Track("A to Z - Wide", waypoints)
pu.plot_trackpoints(track);
plt.savefig("../assets/aToZ-wide-ccw.png");
